# %% [markdown]
# <h1>TESTING PYTHON CODE</h1>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# <h1>DOWNLOADING NECESSARY LIBRARIES</h1>

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC29\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC29\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC29\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC29\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# <h1>IMPORTING LIBRARIES</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#variable _ name / name

# %%
birds = pd.read_csv('datasets\\penguins.csv')

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h1> CHECKING YOUR DATA FRAME FOR NULL VALUES, AND DATA TYPES</h1>

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1>DESCRIPTIVE ANALYSIS</h1>

# %%
birds.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %% [markdown]
# <h1> transpose</h1>

# %%
birds.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h1>FILTERING DATA BASED FROM COLUMS</h1>

# %%
birds['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
birds['weight'] = np.round(birds['body_mass_g'] / 1000, 1)

# %%
birds
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007     3.8
# 1                186.0       3800.0  female  2007     3.8
# ...

# %% [markdown]
# <h1>WHAT TO DO WITH NULL VALUES</h1>

# %%
birds['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           2
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
birds['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
birds['weight'] = birds['weight'].fillna(birds['weight'].mean())

# %%
birds.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %% [markdown]
# <h1>Changing to Category</h1>

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    object
#  8   year               344 non-null    int64
#  9   weight             344 non-null    float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 27.0+ KB

# %%
birds['year'] = birds['year'].astype('category')

# %%
birds['species'] = birds['species'].astype('category')

# %%
birds['rowid'] = birds['rowid'].astype('category')

# %%
birds['island'] = birds['island'].astype('category')

# %%
birds['sex'] = birds['sex'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
birds.head(25)
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen        39.10000       18.70000         181.000000
# 1      2  Adelie  Torgersen        39.50000       17.40000         186.000000
# 2      3  Adelie  Torgersen        40.30000       18.00000         195.000000
# 3      4  Adelie  Torgersen        43.92193       17.15117         200.915205
# 4      5  Adelie  Torgersen        36.70000       19.30000         193.000000
# 5      6  Adelie  Torgersen        39.30000       20.60000         190.000000
# 6      7  Adelie  Torgersen        38.90000       17.80000         181.000000
# 7      8  Adelie  Torgersen        39.20000       19.60000         195.000000
# 8      9  Adelie  Torgersen        34.10000       18.10000         193.000000
# 9     10  Adelie  Torgersen        42.00000       20.20000         190.000000
# 10    11  Adelie  Torgersen        37.80000       17.10000         186.000000
# ...

# %%
birds.tail(15)
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 329   330  Chinstrap  Dream            50.7           19.7              203.0
# 330   331  Chinstrap  Dream            42.5           17.3              187.0
# 331   332  Chinstrap  Dream            52.2           18.8              197.0
# 332   333  Chinstrap  Dream            45.2           16.6              191.0
# 333   334  Chinstrap  Dream            49.3           19.9              203.0
# 334   335  Chinstrap  Dream            50.2           18.8              202.0
# 335   336  Chinstrap  Dream            45.6           19.4              194.0
# 336   337  Chinstrap  Dream            51.9           19.5              206.0
# 337   338  Chinstrap  Dream            46.8           16.5              189.0
# 338   339  Chinstrap  Dream            45.7           17.0              195.0
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# ...

# %%
birds['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
birds[birds['species'] == "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# dtype: int64

# %%
birds[birds['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %%
birds[birds['species'] == "Gentoo"].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# dtype: int64

# %% [markdown]
# <h1>How many Gentoo species have weight more than 3kg?</h1>

# %%
birds['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['body_mass_g'] > 3000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 339    True
# 340    True
# 341    True
# 342    True
# 343    True
# Name: body_mass_g, Length: 344, dtype: bool

# %%
birds[birds['body_mass_g'] > 3000]
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.800000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
(birds['species'] == "Gentoo") & (birds['body_mass_g'] > 3000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
birds[(birds['species'] == "Gentoo") & (birds['body_mass_g'] > 3000)]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %% [markdown]
# <h1>How many Gentoo species have weight less than 3kg?</h1>

# %%
birds['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['body_mass_g'] < 3000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
(birds['species'] == "Gentoo") & (birds['body_mass_g'] < 3000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
birds[(birds['species'] == "Gentoo") & (birds['body_mass_g'] < 3000)]
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %% [markdown]
# <h1>How many Gentoo species have weight greater than 3kg?</h1>

# %%
birds['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['body_mass_g'] > 3000
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 339    True
# 340    True
# 341    True
# 342    True
# 343    True
# Name: body_mass_g, Length: 344, dtype: bool

# %%
(birds['species'] == "Gentoo") & (birds['body_mass_g'] > 3000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
birds[(birds['species'] == "Gentoo") & (birds['body_mass_g'] > 3000)]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %% [markdown]
# <h1>Does Gentoo exclusively live on just one Island?</h1>

# %%
birds['wkilo']= np.round(birds['body_mass_g'] / 1000  , 1 )

# %%
birds
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight  wkilo
# 0           181.000000  3750.000000    male  2007  3.800000    3.8
# 1           186.000000  3800.000000  female  2007  3.800000    3.8
# ...

# %%
birds['species'] == 'Gentoo'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
birds['island'] == 'Biscoe'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
birds['island'] == 'Dream'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: island, Length: 344, dtype: bool

# %%
birds['island'] == 'Torgersen'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %% [markdown]
# <h1> Gentoo in Biscoe</h1>

# %%
(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
gentoo_biscoe = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Biscoe')]

# %%
gentoo_biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight  wkilo
# ...

# %% [markdown]
# <h1> Gentoo in Dream</h1>

# %%
(birds['species'] == 'Gentoo') & (birds['island'] == 'Dream')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
gentoo_dream = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Dream')]

# %%
gentoo_dream
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight, wkilo]
# Index: []

# %% [markdown]
# <h1> Gentoo in Torgersen</h1>

# %%
(birds['species'] == 'Gentoo') & (birds['island'] == 'Torgersen')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
gentoo_torg = birds[(birds['species'] == 'Gentoo') & (birds['island'] == 'Torgersen')]

# %%
gentoo_torg
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight, wkilo]
# Index: []

# %% [markdown]
# <h1>Insight no.1 </h1>
# <h2>Gentoo lives exclusively on the Biscoe island</h2>

# %% [markdown]
# <h1> Adelie in Torgersen</h1>

# %%
(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
adelie_torg = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Torgersen')]

# %%
adelie_torg
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        39.10000       18.70000
# 1       2  Adelie  Torgersen        39.50000       17.40000
# 2       3  Adelie  Torgersen        40.30000       18.00000
# 3       4  Adelie  Torgersen        43.92193       17.15117
# 4       5  Adelie  Torgersen        36.70000       19.30000
# 5       6  Adelie  Torgersen        39.30000       20.60000
# 6       7  Adelie  Torgersen        38.90000       17.80000
# 7       8  Adelie  Torgersen        39.20000       19.60000
# 8       9  Adelie  Torgersen        34.10000       18.10000
# 9      10  Adelie  Torgersen        42.00000       20.20000
# 10     11  Adelie  Torgersen        37.80000       17.10000
# 11     12  Adelie  Torgersen        37.80000       17.30000
# 12     13  Adelie  Torgersen        41.10000       17.60000
# 13     14  Adelie  Torgersen        38.60000       21.20000
# 14     15  Adelie  Torgersen        34.60000       21.10000
# ...

# %% [markdown]
# <h1> Adelie in Biscoe</h1>

# %%
(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
adelie_biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Biscoe')]

# %%
adelie_biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %% [markdown]
# <h1>Adelie in Dream </h1>

# %%
(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
adelie_dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == 'Dream')]

# %%
adelie_dream
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %% [markdown]
# <h1>Insight no. 2</h1>
# <h2>adelie lives on the Three islands</h2>

# %% [markdown]
# <h1>Chinstrap in Biscoe</h1>

# %%
(birds['species'] == 'Chinstrap') & (birds['island'] == 'Biscoe')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
chinstrap_biscoe = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Biscoe')]

# %%
chinstrap_biscoe
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight, wkilo]
# Index: []

# %% [markdown]
# <h1>Chinstrap in Dream</h1>

# %%
(birds['species'] == 'Chinstrap') & (birds['island'] == 'Dream')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Length: 344, dtype: bool

# %%
chinstrap_dream = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Dream')]

# %%
chinstrap_dream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68 entries, 276 to 343
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              68 non-null     category
#  1   species            68 non-null     category
#  2   island             68 non-null     category
#  3   bill_length_mm     68 non-null     float64
#  4   bill_depth_mm      68 non-null     float64
#  5   flipper_length_mm  68 non-null     float64
#  6   body_mass_g        68 non-null     float64
#  7   sex                68 non-null     category
#  8   year               68 non-null     category
#  9   weight             68 non-null     float64
#  10  wkilo              68 non-null     float64
# dtypes: category(5), float64(6)
# memory usage: 15.4 KB

# %% [markdown]
# <h1>Chinstrap in Torgersen</h1>

# %%
(birds['species'] == 'Chinstrap') & (birds['island'] == 'Torgersen')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
chinstrap_torg = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == 'Torgersen')]

# %%
chinstrap_torg
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight, wkilo]
# Index: []

# %% [markdown]
# <h1>Insight no.3</h1>
# <h2> Chinstrap lives exclusively on dream island</h2>

# %% [markdown]
# <h1>Does the island impact the body mass of a penguin specie</h1>

# %%
adelie_biscoe_w = np.round(adelie_biscoe['wkilo'].mean(), 1)

# %%
adelie_biscoe_w
# Out:
# np.float64(3.7)

# %%
adelie_dream_w = np.round(adelie_dream['wkilo'].mean(), 1)

# %%
adelie_dream_w
# Out:
# np.float64(3.7)

# %%
adelie_torg_w =np.round(adelie_torg['wkilo'].mean(), 1)

# %%
adelie_torg_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>Insight no.4 </h1>
# <h2>The island doesn't impact the weight of the adelie species</h2>

# %%
gentoo_biscoe_w = np.round(gentoo_biscoe['wkilo'].mean(), 1)

# %%
gentoo_biscoe_w
# Out:
# np.float64(5.1)

# %%
gentoo_dream_w =np.round(gentoo_dream['wkilo'].mean(), 1)

# %%
gentoo_dream_w
# Out:
# np.float64(nan)

# %%
gentoo_torg_w =np.round(gentoo_torg['wkilo'].mean(), 1)

# %%
gentoo_torg_w
# Out:
# np.float64(nan)

# %% [markdown]
# <h1>Insight no. 5</h1>
# <h2>The island doesn't impact the weight of the gentoo species</h2>

# %%
chinstrap_torg_w =np.round(chinstrap_torg['wkilo'].mean(), 1)

# %%
chinstrap_torg_w
# Out:
# np.float64(nan)

# %%
chinstrap_biscoe_w =np.round(chinstrap_biscoe['wkilo'].mean(), 1)

# %%
chinstrap_biscoe_w
# Out:
# np.float64(nan)

# %%
chinstrap_dream_w =np.round(chinstrap_dream['wkilo'].mean(), 1)

# %%
chinstrap_dream_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>Insight no. 6</h1>
# <h2>The island doesn't impact the weight of the chinstrap species</h2>

# %% [markdown]
# <h1>Insight no. 7</h1>
# <h1>The heaviest species is Gentoo</h1>

# %% [markdown]
# <h1> AGGREGATING DATA</h1>

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
#  10  wkilo              344 non-null    float64
# dtypes: category(5), float64(6)
# memory usage: 29.6 KB

# %%
birds_island = birds.groupby(['species', 'island','sex']).size()
# Out:
# C:\Users\LAB4-StudentPC29\AppData\Local\Temp\ipykernel_19632\1363134309.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_island = birds.groupby(['species', 'island','sex']).size()

# %%
birds_island
# Out:
# species    island     sex
# Adelie     Biscoe     female    22
#                       male      22
#            Dream      female    27
#                       male      29
#            Torgersen  female    24
#                       male      28
# Chinstrap  Biscoe     female     0
#                       male       0
#            Dream      female    34
#                       male      34
#            Torgersen  female     0
#                       male       0
# Gentoo     Biscoe     female    58
#                       male      66
#            Dream      female     0
#                       male       0
#            Torgersen  female     0
#                       male       0
# dtype: int64

# %% [markdown]
# <h1>HOW TO USE GROUPBY</h1>
#
# <ol>
#     <li>Name the group by reference data frame</li>
#     <li>call the dataframe</li>
#     <li>groupby() function</li>
#     <li>colums to group</li>
#     <li>group by function</li>
# </ol>

# %%
birds_agg = birds.groupby(['species','island']).count()
# Out:
# C:\Users\LAB4-StudentPC29\AppData\Local\Temp\ipykernel_19632\3074744728.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg = birds.groupby(['species','island']).count()

# %%
birds_agg
# Out:
#                      rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   island
# Adelie    Biscoe        44              44             44                 44
#           Dream         56              56             56                 56
#           Torgersen     52              52             52                 52
# Chinstrap Biscoe         0               0              0                  0
#           Dream         68              68             68                 68
#           Torgersen      0               0              0                  0
# Gentoo    Biscoe       124             124            124                124
#           Dream          0               0              0                  0
#           Torgersen      0               0              0                  0
#
#                      body_mass_g  sex  year  weight  wkilo
# species   island
# Adelie    Biscoe              44   44    44      44     44
# ...

# %%
birds_agg = birds.groupby(['species','island']).size()
# Out:
# C:\Users\LAB4-StudentPC29\AppData\Local\Temp\ipykernel_19632\2668887436.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg = birds.groupby(['species','island']).size()

# %%
birds_agg
# Out:
# species    island
# Adelie     Biscoe        44
#            Dream         56
#            Torgersen     52
# Chinstrap  Biscoe         0
#            Dream         68
#            Torgersen      0
# Gentoo     Biscoe       124
#            Dream          0
#            Torgersen      0
# dtype: int64

# %%
birds_agg2 = np.round(birds.groupby(['species', 'island'])['weight'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC29\AppData\Local\Temp\ipykernel_19632\183471143.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg2 = np.round(birds.groupby(['species', 'island'])['weight'].mean(),1)

# %%
birds_agg2
# Out:
# species    island
# Adelie     Biscoe       3.7
#            Dream        3.7
#            Torgersen    3.7
# Chinstrap  Biscoe       NaN
#            Dream        3.7
#            Torgersen    NaN
# Gentoo     Biscoe       5.1
#            Dream        NaN
#            Torgersen    NaN
# Name: weight, dtype: float64

# %%
birds_agg3 = birds.groupby(['species','island','year','sex']).size()
# Out:
# C:\Users\LAB4-StudentPC29\AppData\Local\Temp\ipykernel_19632\3026250021.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg3 = birds.groupby(['species','island','year','sex']).size()

# %%
birds_agg3
# Out:
# species    island     year  sex
# Adelie     Biscoe     2007  female     5
#                             male       5
#                       2008  female     9
#                             male       9
#                       2009  female     8
#                             male       8
#            Dream      2007  female     9
#                             male      11
#                       2008  female     8
#                             male       8
#                       2009  female    10
#                             male      10
#            Torgersen  2007  female     8
#                             male      12
#                       2008  female     8
#                             male       8
#                       2009  female     8
#                             male       8
# Chinstrap  Biscoe     2007  female     0
#                             male       0
#                       2008  female     0
#                             male       0
# ...

# %%
birds_agg3.unstack()
# Out:
# sex                       female  male
# species   island    year
# Adelie    Biscoe    2007       5     5
#                     2008       9     9
#                     2009       8     8
#           Dream     2007       9    11
#                     2008       8     8
#                     2009      10    10
#           Torgersen 2007       8    12
#                     2008       8     8
#                     2009       8     8
# Chinstrap Biscoe    2007       0     0
#                     2008       0     0
#                     2009       0     0
#           Dream     2007      13    13
#                     2008       9     9
#                     2009      12    12
#           Torgersen 2007       0     0
#                     2008       0     0
#                     2009       0     0
# Gentoo    Biscoe    2007      16    18
#                     2008      22    24
#                     2009      20    24
#           Dream     2007       0     0
# ...

# %% [markdown]
# <h1>Insight no.8</h1>
# <h2>2007 is the highest recorded year in male adelie in Torgersen island</h2>
# <h2>2007 is the highest recorded year in male Chinstrap in Dream island</h2>
# <h2>2008 is the highest recorded year in male Gentoo in Biscoe island</h2>

# %%
birds_agg4 = np.round(birds.groupby(['species','sex'])['weight'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC29\AppData\Local\Temp\ipykernel_19632\441228957.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg4 = np.round(birds.groupby(['species','sex'])['weight'].mean(),1)

# %%
birds_agg4.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.4

# %% [markdown]
# <h1>Insight no.9</h1>
# <h2>The average weight of Female Adelie is 3.4kg and the average weight for Male Adelie is 4.0kg</h2>

# %% [markdown]
# <h1>Insight no.10</h1>
# <h2>The average weight of Female Chinstrap is 3.5kg and the average weight for Male Chinstrap is 3.9kg</h2>

# %% [markdown]
# <h1>Insight no.11</h1>
# <h2>The average weight of Female Gentoo is 4.7kg and the average weight for Male Gentoo is 5.4kg</h2>

# %% [markdown]
# <h1>Correlation using python and pandas</h1>

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
#  10  wkilo              344 non-null    float64
# dtypes: category(5), float64(6)
# memory usage: 29.6 KB

# %% [markdown]
# <h1>Does the bill length affects the size of the depth?</h1>

# %%
b_dept_length_cor = birds['bill_length_mm'].corr(birds['bill_depth_mm'])

# %%
b_dept_length_cor
# Out:
# np.float64(-0.23505287035553282)

# %% [markdown]
# <h1>Insight no.12</h1>
# <h2> Bill length has no Correlation with bill depth</h2>

# %% [markdown]
# <h1>Does the body mass affects the flipper length?</h1>

# %%
b_mass_flip_cor = birds['body_mass_g'].corr(birds['flipper_length_mm'])

# %%
b_mass_flip_cor
# Out:
# np.float64(0.8712017673060114)

# %% [markdown]
# <h1>Insight no. 13</h1>
# <h3>Body Mass has Correlation with Flipper Length</h3>

# %% [markdown]
# <h1>Does the body mass affects the bill length?</h1>

# %%
b_mass_flip_cor = birds['body_mass_g'].corr(birds['bill_length_mm'])

# %%
b_mass_flip_cor
# Out:
# np.float64(0.5951098244376305)

# %% [markdown]
# <h1>Insight no. 14</h1>
# <h3>Body Mass has Correlation with Bill Length</h3>

# %% [markdown]
# <h1>Does the body mass affects the Bill depth?</h1>

# %%
b_mass_flip_cor = birds['body_mass_g'].corr(birds['bill_depth_mm'])

# %%
b_mass_flip_cor
# Out:
# np.float64(-0.47191562118606645)

# %% [markdown]
# <h1>Insight no. 15</h1>
# <h3>Body Mass has no Correlation with Bill Depth</h3>

# %% [markdown]
# <h1>Correlation Between Qualitative and Quantitative</h1>
# <h2>Sex and Body Mass</h2>

# %% [markdown]
# <h1>Library for ONE WAY ANNOVA -- SCIENCE PYTHON (scipy)</h1>

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC29\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h3>Requirements for one way annova</h3>
# <h4>Filter columns and its data</h4>

# %%
birds[birds['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
birds[birds['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
f_stats, p_value = f_oneway(birds[birds['sex'] == 'male']['body_mass_g'],
                             birds[birds['sex'] == 'female']['body_mass_g'])
print(p_value)
# Out:
# 3.0226600487050246e-15

# %% [markdown]
# <h1>Insight no.16</h1>
# <h3>There is a correlation between sex and body mass</h3>
